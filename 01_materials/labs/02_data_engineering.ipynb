# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in Dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss Dask vs. Pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance, and the data, along with its description, is available via [Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset).
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# <div>
# <image src="./images/02_medallion_architecture.png" height=300>
# </div>
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class to control the process of obtaining and transforming our data.
#
# <div>
# <image src="./images/02_target_pipeline_manager.png" height=250>
# </div>

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account. Alternatively, download the file from [this location](https://drive.google.com/drive/folders/1AA4gapDLpI194TGce1bY25sd91Km-tU3?usp=drive_link).
#
# + Extract stock prices (not ETFs) into the directory: `./05_src/data/prices_csv/`.
# + To be clear, your folder structure should include the path `05_src/data/prices_csv/stocks`.

# %% [markdown]
# The command `%run update_path.py` runs a local script that adds the repository's `./05_src/` directory to the Notebook's kernel path. This way, we can use our modules within the notebook.

# %%
# %run update_path.py

# %% [markdown]
# To load the historical price data for stocks and ETFs, use the code below. Notice the following:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager. Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by [Python's documentation](https://docs.python.org/2/howto/logging.html#logging-advanced-tutorial).

# %%
from glob import glob
import os
import pandas as pd
import random

from utils.logger import get_logger
_logs = get_logger(__name__)

# %% [markdown]
# + The [`glob` module](https://docs.python.org/3/library/glob.html) is used for finding path names that match specified patterns using Unix shell-style rules.
#
# + Notice that the module `glob` contains a function called `glob`; therefore, we used `from glob import glob` above.
#
# + The path in which we are searching for our csv files is produced by joining two strings:
#
#
#
#     - The value of the environment variable 'SRC_DIR' that we obtain with `os.getenv('SRC_DIR')` (this variable points to ./05_src).
#
#     - Another string given by "data/prices_csv/stocks/*.csv".
#
#     - Both strings are combined into an OS-consistent path using `os.path.join(...)`.
#
# + After we know the location of all our files, we sample a subset of them.

# %%
stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))
_logs.info(f'Found {len(stock_files)} stock price files in {os.getenv("SRC_DIR")}.')

random.seed(42)
n_sample = 60
stock_files = random.sample(stock_files, n_sample)
_logs.info(f'Sampled {n_sample} stock price files for processing. The files are: {stock_files   }')
# Out:
# 2026-01-29 14:26:14,771, 2178150814.py, 2, INFO, Found 5884 stock price files in ../../05_src/.
# 2026-01-29 14:26:14,773, 2178150814.py, 7, INFO, Sampled 60 stock price files for processing. The files are: ['../../05_src/data/prices_csv/stocks\\TNC.csv', '../../05_src/data/prices_csv/stocks\\CBB.csv', '../../05_src/data/prices_csv/stocks\\ALDX.csv', '../../05_src/data/prices_csv/stocks\\GLADD.csv', '../../05_src/data/prices_csv/stocks\\FIXX.csv', '../../05_src/data/prices_csv/stocks\\ETJ.csv', '../../05_src/data/prices_csv/stocks\\CMCTP.csv', '../../05_src/data/prices_csv/stocks\\BWG.csv', '../../05_src/data/prices_csv/stocks\\VIAC.csv', '../../05_src/data/prices_csv/stocks\\REI.csv', '../../05_src/data/prices_csv/stocks\\BLPH.csv', '../../05_src/data/prices_csv/stocks\\SMG.csv', '../../05_src/data/prices_csv/stocks\\MOH.csv', '../../05_src/data/prices_csv/stocks\\AMH.csv', '../../05_src/data/prices_csv/stocks\\AMAL.csv', '../../05_src/data/prices_csv/stocks\\BPYPN.csv', '../../05_src/data/prices_csv/stocks\\ERH.csv', '../../05_src/data/prices_csv/stocks\\FAMI.csv', '../../05_src/data/prices_csv/stocks\\PFG.csv', '../../05_src/data/prices_csv/stocks\\SPXC.csv', '../../05_src/data/prices_csv/stocks\\ALL.csv', '../../05_src/data/prices_csv/stocks\\RTTR.csv', '../../05_src/data/prices_csv/stocks\\EARN.csv', '../../05_src/data/prices_csv/stocks\\ZIXI.csv', '../../05_src/data/prices_csv/stocks\\TSN.csv', '../../05_src/data/prices_csv/stocks\\WST.csv', '../../05_src/data/prices_csv/stocks\\REG.csv', '../../05_src/data/prices_csv/stocks\\MNK.csv', '../../05_src/data/prices_csv/stocks\\ESGR.csv', '../../05_src/data/prices_csv/stocks\\NGD.csv', '../../05_src/data/prices_csv/stocks\\SLRX.csv', '../../05_src/data/prices_csv/stocks\\GLW.csv', '../../05_src/data/prices_csv/stocks\\ACN.csv', '../../05_src/data/prices_csv/stocks\\CSSE.csv', '../../05_src/data/prices_csv/stocks\\WORK.csv', '../../05_src/data/prices_csv/stocks\\MOS.csv', '../../05_src/data/prices_csv/stocks\\IPWR.csv', '../../05_src/data/prices_csv/stocks\\GLUU.csv', '../../05_src/data/prices_csv/stocks\\CRMT.csv', '../../05_src/data/prices_csv/stocks\\EOLS.csv', '../../05_src/data/prices_csv/stocks\\INSU.csv', '../../05_src/data/prices_csv/stocks\\BWEN.csv', '../../05_src/data/prices_csv/stocks\\BPMX.csv', '../../05_src/data/prices_csv/stocks\\LH.csv', '../../05_src/data/prices_csv/stocks\\BRQS.csv', '../../05_src/data/prices_csv/stocks\\KALU.csv', '../../05_src/data/prices_csv/stocks\\ITCB.csv', '../../05_src/data/prices_csv/stocks\\SRE.csv', '../../05_src/data/prices_csv/stocks\\GAZ.csv', '../../05_src/data/prices_csv/stocks\\AQMS.csv', '../../05_src/data/prices_csv/stocks\\NPK.csv', '../../05_src/data/prices_csv/stocks\\QRHC.csv', '../../05_src/data/prices_csv/stocks\\CGEN.csv', '../../05_src/data/prices_csv/stocks\\LEVL.csv', '../../05_src/data/prices_csv/stocks\\BGS.csv', '../../05_src/data/prices_csv/stocks\\RIV.csv', '../../05_src/data/prices_csv/stocks\\GURE.csv', '../../05_src/data/prices_csv/stocks\\TEF.csv', '../../05_src/data/prices_csv/stocks\\SYNH.csv', '../../05_src/data/prices_csv/stocks\\KEY.csv']

# %% [markdown]
# We load the sampled files into dataframes and concatenate them:
#
# + Start with an empty list.
# + Read each file into a dataframe and [`append()` it to the list](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists). Notice that `append()` is an in-place operation (it does not return a list, it modifies the list in place).
# + Finally, we concatenate all dataframes along the vertical axis (`axis=0`) using [`pd.concat()`](https://pandas.pydata.org/docs/user_guide/merging.html#concat).
# + Notice that we do not concatenate each time that we load a dataframe. According to [Panda's documentation](https://pandas.pydata.org/docs/user_guide/merging.html#concat):
#
# > "`concat()` makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`."

# %%
dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    dt_list.append(dt)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)
# Out:
# 2026-01-29 14:28:52,513, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TNC.csv
# 2026-01-29 14:28:52,647, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CBB.csv
# 2026-01-29 14:28:52,681, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ALDX.csv
# 2026-01-29 14:28:52,696, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLADD.csv
# 2026-01-29 14:28:52,718, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\FIXX.csv
# 2026-01-29 14:28:52,739, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ETJ.csv
# 2026-01-29 14:28:52,766, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CMCTP.csv
# 2026-01-29 14:28:52,785, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BWG.csv
# 2026-01-29 14:28:52,796, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\VIAC.csv
# 2026-01-29 14:28:52,833, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\REI.csv
# 2026-01-29 14:28:52,870, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BLPH.csv
# 2026-01-29 14:28:52,889, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SMG.csv
# 2026-01-29 14:28:52,933, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MOH.csv
# 2026-01-29 14:28:52,968, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AMH.csv
# 2026-01-29 14:28:52,986, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AMAL.csv
# 2026-01-29 14:28:52,999, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BPYPN.csv
# 2026-01-29 14:28:53,016, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ERH.csv
# 2026-01-29 14:28:53,051, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\FAMI.csv
# 2026-01-29 14:28:53,074, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\PFG.csv
# 2026-01-29 14:28:53,119, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SPXC.csv
# 2026-01-29 14:28:53,163, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ALL.csv
# 2026-01-29 14:28:53,208, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\RTTR.csv
# 2026-01-29 14:28:53,219, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\EARN.csv
# 2026-01-29 14:28:53,227, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ZIXI.csv
# 2026-01-29 14:28:53,276, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TSN.csv
# 2026-01-29 14:28:53,311, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\WST.csv
# 2026-01-29 14:28:53,367, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\REG.csv
# 2026-01-29 14:28:53,393, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MNK.csv
# 2026-01-29 14:28:53,431, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ESGR.csv
# 2026-01-29 14:28:53,465, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\NGD.csv
# 2026-01-29 14:28:53,489, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SLRX.csv
# 2026-01-29 14:28:53,502, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLW.csv
# 2026-01-29 14:28:53,534, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ACN.csv
# 2026-01-29 14:28:53,561, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CSSE.csv
# 2026-01-29 14:28:53,577, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\WORK.csv
# 2026-01-29 14:28:53,586, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MOS.csv
# 2026-01-29 14:28:53,620, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\IPWR.csv
# 2026-01-29 14:28:53,634, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLUU.csv
# 2026-01-29 14:28:53,664, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CRMT.csv
# 2026-01-29 14:28:53,702, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\EOLS.csv
# 2026-01-29 14:28:53,717, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\INSU.csv
# 2026-01-29 14:28:53,731, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BWEN.csv
# 2026-01-29 14:28:53,751, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BPMX.csv
# 2026-01-29 14:28:53,770, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\LH.csv
# 2026-01-29 14:28:53,799, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BRQS.csv
# 2026-01-29 14:28:53,814, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\KALU.csv
# 2026-01-29 14:28:53,841, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ITCB.csv
# 2026-01-29 14:28:53,864, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SRE.csv
# 2026-01-29 14:28:53,886, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GAZ.csv
# 2026-01-29 14:28:53,901, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AQMS.csv
# 2026-01-29 14:28:53,918, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\NPK.csv
# 2026-01-29 14:28:53,947, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\QRHC.csv
# 2026-01-29 14:28:53,972, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CGEN.csv
# 2026-01-29 14:28:54,001, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\LEVL.csv
# 2026-01-29 14:28:54,021, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BGS.csv
# 2026-01-29 14:28:54,049, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\RIV.csv
# 2026-01-29 14:28:54,082, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GURE.csv
# 2026-01-29 14:28:54,119, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TEF.csv
# 2026-01-29 14:28:54,146, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SYNH.csv
# 2026-01-29 14:28:54,168, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\KEY.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data using the [`info()` dataframe method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html):

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239659 entries, 0 to 239658
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       239659 non-null  datetime64[ns]
#  1   Open       239656 non-null  float64
#  2   High       239656 non-null  float64
#  3   Low        239656 non-null  float64
#  4   Close      239656 non-null  float64
#  5   Adj Close  239656 non-null  float64
#  6   Volume     239656 non-null  float64
#  7   source     239659 non-null  object
#  8   ticker     239659 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 16.5+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. Good references for this type of data manipulation are:
#
# + [Panda's Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data).
# + [Panda's Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['TNC',
#  'CBB',
#  'ALDX',
#  'GLADD',
#  'FIXX',
#  'ETJ',
#  'CMCTP',
#  'BWG',
#  'VIAC',
#  'REI',
#  'BLPH',
#  'SMG',
#  'MOH',
#  'AMH',
#  'AMAL',
#  'BPYPN',
#  'ERH',
#  'FAMI',
#  'PFG',
#  'SPXC',
#  'ALL',
#  'RTTR',
#  'EARN',
#  'ZIXI',
#  'TSN',
#  'WST',
#  'REG',
#  'MNK',
#  'ESGR',
#  'NGD',
#  'SLRX',
#  'GLW',
#  'ACN',
#  'CSSE',
#  'WORK',
#  'MOS',
#  'IPWR',
#  'GLUU',
#  'CRMT',
#  'EOLS',
#  'INSU',
#  'BWEN',
#  'BPMX',
#  'LH',
#  'BRQS',
#  'KALU',
#  'ITCB',
#  'SRE',
#  'GAZ',
#  'AQMS',
#  'NPK',
#  'QRHC',
#  'CGEN',
#  'LEVL',
#  'BGS',
#  'RIV',
#  'GURE',
#  'TEF',
#  'SYNH',
#  'KEY']

# %% [markdown]
# # Storing Data in CSV
#
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parquet, by measuring their performance:
#
#     - Time to save: We will measure time by using the `time` library.
#     - Space required on drive: We will use the custom function below.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %% [markdown]
# Load the specification of a temporary directory from the environment  and create a subdirectory in it called "csv":
#
# + Use `os.getenv("TEMP_DATA")` to obtain the desired location of the temporary folder from an environment variable.
# + If the subdirectory exists, delete it using `shutil.rmtree()`; the flag `ignore_errors=True` helps us in case the subdirectory does not exist (for instance, in the first run).
# + Create a directory with path given by `csv_dir` using `os.makedirs()`; the flag `exist_ok=True` indicates that if the directory already exists, then the function will do nothing.
# + Finally, create the stock price file location, `stock_csv`, which will be used to create the csv file.

# %%
import shutil

temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")

shutil.rmtree(csv_dir, ignore_errors=True)
os.makedirs(csv_dir, exist_ok=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")

# %% [markdown]
# Save the concatenated dataframe to a CSV file. We measure the time elapsed by storing the start and end times, then we calculate their difference in seconds.

# %%
import time

start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2026-01-29 14:37:26,303, 807204384.py, 7, INFO, Writing data ((239659, 9)) to csv took 1.2895572185516357 seconds.
# 2026-01-29 14:37:26,303, 807204384.py, 8, INFO, CSV file size 26.618403999999998 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Notes on Dask
#
# We could use Pandas to save the data directly into Parquet files. However, we will use a different approach by applying the [Dask framework](https://www.dask.org/). Dask provides functionality for working with datasets that do not fit in memory and parallelization to speed up computation. A few notes on Dask and Pandas:
#
# - Pandas, Parquet, and Arrow:
#
#     + We can work with large datasets and Parquet files in Pandas, but we will generally be limited by the amount of data that can fit in our computer's memory.
#     + Pandas can write Parquet files using a PyArrow backend. In fact, recent versions of Pandas support PyArrow data types, and future versions will require a PyArrow backend.
#     + The PyArrow library is an interface between Python and the Apache Arrow project. In particular, the [Parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are Apache projects.
#
# - Dask
#
#     + Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on Pandas-like dataframes.
#     + Dask is also relatively easy to use as it mimics Pandas' API.
#     + Dask allows us to work with larger datasets than Pandas. In a sense, it is an intermediate step between Pandas and big-data frameworks like Spark (or Databricks).
#     + If you are familiar with Pandas, a good introduction is [10 Minutes to Dask](https://docs.dask.org/en/stable/10-minutes-to-dask.html).

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2026-01-29 14:38:04,168, 817812245.py, 7, INFO, Writing dd ((239659, 9)) to parquet took 1.1959078311920166 seconds.
# 2026-01-29 14:38:04,173, 817812245.py, 8, INFO, Parquet file size 9.718058 MB

# %% [markdown]
# ### Pandas, Dask, and Parquet
#
# The distinction of Pandas Dataframes, Dask Dataframes, and Parquet files is important:
#
# + Pandas dataframes combine the functionality of [NumPy](https://numpy.org/) (efficient vector operations, especially vector algebra) with a concise data manipulation framework that allows us to create columns of different data types (NumPy only allows single-type matrices), database-like operations (such as filtering rows, subsetting columns, and joining different dataframes).
# + Dask dataframes extend the functionality of Pandas dataframes beyond the confines of available memory and implement parallelized operations, among other benefits.
# + Parquet files are a file format. Parquet files can be created by Pandas and Dask, but Dask offers a superior interface. Parquet files are immutable: once written, they cannot be modified.
# + Parquet and Dask are not the same: Parquet is a file format that can be accessed by many applications and programming languages (Python, R, Power BI, etc.), while Dask is a Python package for working with large datasets using distributed computation.

# %% [markdown]
# ### Dask is Powerful, but not Infallible
#
# It is tempting to think of Dask as a super-Pandas, but each package has its advantages and disadvantages.
#
# + Dask is not good at everything (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
# + A useful and somewhat idiosyncratic comparison of various data manipulation frameworks is shown below (from [DataFrames at Scale Comparison: TPC-H](https://docs.coiled.io/blog/tpch.html#when-to-use-duckdb-vs-polars-vs-dask-vs-spark))
#
# Concept              | Spark | Dask | DuckDB | Polars
# ---------------------|-------|------|--------|--------
# Fast Locally         | ❌    | 🤔  | ✅     | ✅
# Fast on Cloud (1 TB) | ✅    | ✅  | ✅     | ❌
# Fast on Cloud (10 TB)| ❌    | ✅  | ✅     | ❌
# Scales Out           | ✅    | ✅  | ❌     | ❌
# SQL                  | ✅    | 🤔  | ✅     | 🤔
# More than SQL        | ✅    | ✅  | ❌     | ✅
# Sensible Defaults    | ❌    | ✅  | ✅     | ✅
#
#
# ### Dask Best Practices
#
# Parallelism brings extra complexity and overhead. Here are a few ideas to help you decide when to use Dask (from [Dask's Best Practices](https://docs.dask.org/en/stable/best-practices.html)):
#
# #### Small is Better
#
# + Start small: if possible, use Pandas. Also, try to reduce your data using aggregation, then use Pandas.
# + More generally, NumPy, Pandas, and Scikit-Learn may have faster functions for what you need. Consult the relevant documentation, experiment, and/or consult with a colleague or expert.
#
# #### Index with Care
#
# + Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
# + Minimize full-data shuffling as much as possible: indexing is an expensive operation.
#
# ### Consider the Cost of Joins
#
# + Consider cases such as small-to-large joins, where the small dataframe fits in memory, but the large one does not. The small dataframe can be Pandas, while the larger one is a Dask dataframe.
# + Some joins are more expensive than others.
#
#     * Not expensive:
#
#         - Join a Dask DataFrame with a Pandas DataFrame.
#         - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#         - Join Dask DataFrames along their indexes.
#
#     * Expensive:
#
#         - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How Do We Store Prices?
#
# + We can store our data as a single blob.
#
#   - This can be difficult to maintain, especially because parquet files are immutable.
#   - Using a single file, we would need to recreate the complete file any time that we update it.
#
# + An alternative strategy is to organize data files by ticker and date:
#
#   - We can create one file per ticker and month (or any other suitable frequency).
#   - Under this approach, we would only need to recreate the latest month's file at any update.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    # Filter data for ticker
    # Notice that these are Pandas dataframes
    _logs.info(f'Processing ticker: {ticker}')
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        _logs.info(f'Processing year {yr} for ticker {ticker}.')
        # Filter data for year and convert to Dask dataframe
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        
        # Define path and create directories if not exist
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        _logs.info(f'Writing data to path: {yr_path}')

        # Write to Parquet
        yr_dd.to_parquet(yr_path, engine = "pyarrow")
# Out:
# 2026-01-29 14:50:01,608, 2113979629.py, 4, INFO, Processing ticker: TNC
# 2026-01-29 14:50:01,647, 2113979629.py, 8, INFO, Processing year 1973 for ticker TNC.
# 2026-01-29 14:50:01,652, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1973
# 2026-01-29 14:50:01,686, 2113979629.py, 8, INFO, Processing year 1974 for ticker TNC.
# 2026-01-29 14:50:01,690, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1974
# 2026-01-29 14:50:01,718, 2113979629.py, 8, INFO, Processing year 1975 for ticker TNC.
# 2026-01-29 14:50:01,718, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1975
# 2026-01-29 14:50:01,743, 2113979629.py, 8, INFO, Processing year 1976 for ticker TNC.
# 2026-01-29 14:50:01,747, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1976
# 2026-01-29 14:50:01,772, 2113979629.py, 8, INFO, Processing year 1977 for ticker TNC.
# 2026-01-29 14:50:01,779, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1977
# 2026-01-29 14:50:01,800, 2113979629.py, 8, INFO, Processing year 1978 for ticker TNC.
# 2026-01-29 14:50:01,800, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1978
# 2026-01-29 14:50:01,830, 2113979629.py, 8, INFO, Processing year 1979 for ticker TNC.
# 2026-01-29 14:50:01,830, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1979
# 2026-01-29 14:50:01,845, 2113979629.py, 8, INFO, Processing year 1980 for ticker TNC.
# 2026-01-29 14:50:01,862, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1980
# 2026-01-29 14:50:01,879, 2113979629.py, 8, INFO, Processing year 1981 for ticker TNC.
# 2026-01-29 14:50:01,879, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1981
# 2026-01-29 14:50:01,910, 2113979629.py, 8, INFO, Processing year 1982 for ticker TNC.
# 2026-01-29 14:50:01,920, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1982
# 2026-01-29 14:50:01,945, 2113979629.py, 8, INFO, Processing year 1983 for ticker TNC.
# 2026-01-29 14:50:01,945, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1983
# 2026-01-29 14:50:01,960, 2113979629.py, 8, INFO, Processing year 1984 for ticker TNC.
# 2026-01-29 14:50:01,975, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1984
# 2026-01-29 14:50:01,994, 2113979629.py, 8, INFO, Processing year 1985 for ticker TNC.
# 2026-01-29 14:50:02,008, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1985
# 2026-01-29 14:50:02,027, 2113979629.py, 8, INFO, Processing year 1986 for ticker TNC.
# 2026-01-29 14:50:02,027, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1986
# 2026-01-29 14:50:02,068, 2113979629.py, 8, INFO, Processing year 1987 for ticker TNC.
# 2026-01-29 14:50:02,075, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1987
# 2026-01-29 14:50:02,094, 2113979629.py, 8, INFO, Processing year 1988 for ticker TNC.
# 2026-01-29 14:50:02,094, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1988
# 2026-01-29 14:50:02,134, 2113979629.py, 8, INFO, Processing year 1989 for ticker TNC.
# 2026-01-29 14:50:02,142, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1989
# 2026-01-29 14:50:02,165, 2113979629.py, 8, INFO, Processing year 1990 for ticker TNC.
# 2026-01-29 14:50:02,165, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1990
# 2026-01-29 14:50:02,193, 2113979629.py, 8, INFO, Processing year 1991 for ticker TNC.
# 2026-01-29 14:50:02,194, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1991
# 2026-01-29 14:50:02,221, 2113979629.py, 8, INFO, Processing year 1992 for ticker TNC.
# 2026-01-29 14:50:02,232, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1992
# 2026-01-29 14:50:02,243, 2113979629.py, 8, INFO, Processing year 1993 for ticker TNC.
# 2026-01-29 14:50:02,243, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1993
# 2026-01-29 14:50:02,283, 2113979629.py, 8, INFO, Processing year 1994 for ticker TNC.
# 2026-01-29 14:50:02,283, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1994
# 2026-01-29 14:50:02,306, 2113979629.py, 8, INFO, Processing year 1995 for ticker TNC.
# 2026-01-29 14:50:02,313, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1995
# 2026-01-29 14:50:02,333, 2113979629.py, 8, INFO, Processing year 1996 for ticker TNC.
# 2026-01-29 14:50:02,333, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1996
# 2026-01-29 14:50:02,360, 2113979629.py, 8, INFO, Processing year 1997 for ticker TNC.
# 2026-01-29 14:50:02,365, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1997
# 2026-01-29 14:50:02,380, 2113979629.py, 8, INFO, Processing year 1998 for ticker TNC.
# 2026-01-29 14:50:02,394, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1998
# 2026-01-29 14:50:02,415, 2113979629.py, 8, INFO, Processing year 1999 for ticker TNC.
# 2026-01-29 14:50:02,420, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1999
# 2026-01-29 14:50:02,443, 2113979629.py, 8, INFO, Processing year 2000 for ticker TNC.
# 2026-01-29 14:50:02,454, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2000
# 2026-01-29 14:50:02,478, 2113979629.py, 8, INFO, Processing year 2001 for ticker TNC.
# 2026-01-29 14:50:02,499, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2001
# 2026-01-29 14:50:02,509, 2113979629.py, 8, INFO, Processing year 2002 for ticker TNC.
# 2026-01-29 14:50:02,524, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2002
# 2026-01-29 14:50:02,558, 2113979629.py, 8, INFO, Processing year 2003 for ticker TNC.
# 2026-01-29 14:50:02,566, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2003
# 2026-01-29 14:50:02,575, 2113979629.py, 8, INFO, Processing year 2004 for ticker TNC.
# 2026-01-29 14:50:02,593, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2004
# 2026-01-29 14:50:02,616, 2113979629.py, 8, INFO, Processing year 2005 for ticker TNC.
# 2026-01-29 14:50:02,616, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2005
# 2026-01-29 14:50:02,645, 2113979629.py, 8, INFO, Processing year 2006 for ticker TNC.
# 2026-01-29 14:50:02,649, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2006
# 2026-01-29 14:50:02,663, 2113979629.py, 8, INFO, Processing year 2007 for ticker TNC.
# 2026-01-29 14:50:02,677, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2007
# 2026-01-29 14:50:02,699, 2113979629.py, 8, INFO, Processing year 2008 for ticker TNC.
# 2026-01-29 14:50:02,708, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2008
# 2026-01-29 14:50:02,731, 2113979629.py, 8, INFO, Processing year 2009 for ticker TNC.
# 2026-01-29 14:50:02,731, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2009
# 2026-01-29 14:50:02,767, 2113979629.py, 8, INFO, Processing year 2010 for ticker TNC.
# 2026-01-29 14:50:02,771, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2010
# 2026-01-29 14:50:02,783, 2113979629.py, 8, INFO, Processing year 2011 for ticker TNC.
# 2026-01-29 14:50:02,796, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2011
# 2026-01-29 14:50:02,808, 2113979629.py, 8, INFO, Processing year 2012 for ticker TNC.
# 2026-01-29 14:50:02,808, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2012
# 2026-01-29 14:50:02,849, 2113979629.py, 8, INFO, Processing year 2013 for ticker TNC.
# 2026-01-29 14:50:02,849, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2013
# 2026-01-29 14:50:02,874, 2113979629.py, 8, INFO, Processing year 2014 for ticker TNC.
# 2026-01-29 14:50:02,880, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2014
# 2026-01-29 14:50:02,894, 2113979629.py, 8, INFO, Processing year 2015 for ticker TNC.
# 2026-01-29 14:50:02,908, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2015
# 2026-01-29 14:50:02,926, 2113979629.py, 8, INFO, Processing year 2016 for ticker TNC.
# 2026-01-29 14:50:02,926, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2016
# 2026-01-29 14:50:02,964, 2113979629.py, 8, INFO, Processing year 2017 for ticker TNC.
# 2026-01-29 14:50:02,965, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2017
# 2026-01-29 14:50:02,997, 2113979629.py, 8, INFO, Processing year 2018 for ticker TNC.
# 2026-01-29 14:50:03,003, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2018
# 2026-01-29 14:50:03,009, 2113979629.py, 8, INFO, Processing year 2019 for ticker TNC.
# 2026-01-29 14:50:03,027, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2019
# 2026-01-29 14:50:03,063, 2113979629.py, 8, INFO, Processing year 2020 for ticker TNC.
# 2026-01-29 14:50:03,063, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_2020
# 2026-01-29 14:50:03,092, 2113979629.py, 4, INFO, Processing ticker: CBB
# 2026-01-29 14:50:03,108, 2113979629.py, 8, INFO, Processing year 1980 for ticker CBB.
# 2026-01-29 14:50:03,111, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1980
# 2026-01-29 14:50:03,131, 2113979629.py, 8, INFO, Processing year 1981 for ticker CBB.
# 2026-01-29 14:50:03,131, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1981
# 2026-01-29 14:50:03,164, 2113979629.py, 8, INFO, Processing year 1982 for ticker CBB.
# 2026-01-29 14:50:03,169, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1982
# 2026-01-29 14:50:03,192, 2113979629.py, 8, INFO, Processing year 1983 for ticker CBB.
# 2026-01-29 14:50:03,192, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1983
# 2026-01-29 14:50:03,228, 2113979629.py, 8, INFO, Processing year 1984 for ticker CBB.
# 2026-01-29 14:50:03,228, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1984
# 2026-01-29 14:50:03,255, 2113979629.py, 8, INFO, Processing year 1985 for ticker CBB.
# 2026-01-29 14:50:03,263, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1985
# 2026-01-29 14:50:03,277, 2113979629.py, 8, INFO, Processing year 1986 for ticker CBB.
# 2026-01-29 14:50:03,277, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1986
# 2026-01-29 14:50:03,309, 2113979629.py, 8, INFO, Processing year 1987 for ticker CBB.
# 2026-01-29 14:50:03,309, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1987
# 2026-01-29 14:50:03,342, 2113979629.py, 8, INFO, Processing year 1988 for ticker CBB.
# 2026-01-29 14:50:03,371, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1988
# 2026-01-29 14:50:03,395, 2113979629.py, 8, INFO, Processing year 1989 for ticker CBB.
# 2026-01-29 14:50:03,395, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1989
# 2026-01-29 14:50:03,424, 2113979629.py, 8, INFO, Processing year 1990 for ticker CBB.
# 2026-01-29 14:50:03,434, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1990
# 2026-01-29 14:50:03,463, 2113979629.py, 8, INFO, Processing year 1991 for ticker CBB.
# 2026-01-29 14:50:03,463, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1991
# 2026-01-29 14:50:03,492, 2113979629.py, 8, INFO, Processing year 1992 for ticker CBB.
# 2026-01-29 14:50:03,495, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1992
# 2026-01-29 14:50:03,511, 2113979629.py, 8, INFO, Processing year 1993 for ticker CBB.
# 2026-01-29 14:50:03,528, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1993
# 2026-01-29 14:50:03,544, 2113979629.py, 8, INFO, Processing year 1994 for ticker CBB.
# 2026-01-29 14:50:03,544, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1994
# 2026-01-29 14:50:03,576, 2113979629.py, 8, INFO, Processing year 1995 for ticker CBB.
# 2026-01-29 14:50:03,585, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1995
# 2026-01-29 14:50:03,616, 2113979629.py, 8, INFO, Processing year 1996 for ticker CBB.
# 2026-01-29 14:50:03,616, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1996
# 2026-01-29 14:50:03,640, 2113979629.py, 8, INFO, Processing year 1997 for ticker CBB.
# 2026-01-29 14:50:03,652, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1997
# 2026-01-29 14:50:03,679, 2113979629.py, 8, INFO, Processing year 1998 for ticker CBB.
# 2026-01-29 14:50:03,679, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1998
# 2026-01-29 14:50:03,708, 2113979629.py, 8, INFO, Processing year 1999 for ticker CBB.
# 2026-01-29 14:50:03,716, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_1999
# 2026-01-29 14:50:03,728, 2113979629.py, 8, INFO, Processing year 2000 for ticker CBB.
# 2026-01-29 14:50:03,742, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2000
# 2026-01-29 14:50:03,768, 2113979629.py, 8, INFO, Processing year 2001 for ticker CBB.
# 2026-01-29 14:50:03,768, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2001
# 2026-01-29 14:50:03,793, 2113979629.py, 8, INFO, Processing year 2002 for ticker CBB.
# 2026-01-29 14:50:03,796, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2002
# 2026-01-29 14:50:03,822, 2113979629.py, 8, INFO, Processing year 2003 for ticker CBB.
# 2026-01-29 14:50:03,829, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2003
# 2026-01-29 14:50:03,846, 2113979629.py, 8, INFO, Processing year 2004 for ticker CBB.
# 2026-01-29 14:50:03,846, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2004
# 2026-01-29 14:50:03,873, 2113979629.py, 8, INFO, Processing year 2005 for ticker CBB.
# 2026-01-29 14:50:03,879, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2005
# 2026-01-29 14:50:03,895, 2113979629.py, 8, INFO, Processing year 2006 for ticker CBB.
# 2026-01-29 14:50:03,905, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2006
# 2026-01-29 14:50:03,929, 2113979629.py, 8, INFO, Processing year 2007 for ticker CBB.
# 2026-01-29 14:50:03,933, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2007
# 2026-01-29 14:50:03,947, 2113979629.py, 8, INFO, Processing year 2008 for ticker CBB.
# 2026-01-29 14:50:03,959, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2008
# 2026-01-29 14:50:03,978, 2113979629.py, 8, INFO, Processing year 2009 for ticker CBB.
# 2026-01-29 14:50:03,988, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2009
# 2026-01-29 14:50:04,016, 2113979629.py, 8, INFO, Processing year 2010 for ticker CBB.
# 2026-01-29 14:50:04,025, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2010
# 2026-01-29 14:50:04,050, 2113979629.py, 8, INFO, Processing year 2011 for ticker CBB.
# 2026-01-29 14:50:04,057, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2011
# 2026-01-29 14:50:04,079, 2113979629.py, 8, INFO, Processing year 2012 for ticker CBB.
# 2026-01-29 14:50:04,079, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2012
# 2026-01-29 14:50:04,116, 2113979629.py, 8, INFO, Processing year 2013 for ticker CBB.
# 2026-01-29 14:50:04,127, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2013
# 2026-01-29 14:50:04,151, 2113979629.py, 8, INFO, Processing year 2014 for ticker CBB.
# 2026-01-29 14:50:04,156, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2014
# 2026-01-29 14:50:04,177, 2113979629.py, 8, INFO, Processing year 2015 for ticker CBB.
# 2026-01-29 14:50:04,190, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2015
# 2026-01-29 14:50:04,214, 2113979629.py, 8, INFO, Processing year 2016 for ticker CBB.
# 2026-01-29 14:50:04,214, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2016
# 2026-01-29 14:50:04,250, 2113979629.py, 8, INFO, Processing year 2017 for ticker CBB.
# 2026-01-29 14:50:04,258, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2017
# 2026-01-29 14:50:04,279, 2113979629.py, 8, INFO, Processing year 2018 for ticker CBB.
# 2026-01-29 14:50:04,279, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2018
# 2026-01-29 14:50:04,315, 2113979629.py, 8, INFO, Processing year 2019 for ticker CBB.
# 2026-01-29 14:50:04,326, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2019
# 2026-01-29 14:50:04,352, 2113979629.py, 8, INFO, Processing year 2020 for ticker CBB.
# 2026-01-29 14:50:04,363, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CBB\CBB_2020
# 2026-01-29 14:50:04,412, 2113979629.py, 4, INFO, Processing ticker: ALDX
# 2026-01-29 14:50:04,433, 2113979629.py, 8, INFO, Processing year 2014 for ticker ALDX.
# 2026-01-29 14:50:04,444, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2014
# 2026-01-29 14:50:04,483, 2113979629.py, 8, INFO, Processing year 2015 for ticker ALDX.
# 2026-01-29 14:50:04,494, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2015
# 2026-01-29 14:50:04,528, 2113979629.py, 8, INFO, Processing year 2016 for ticker ALDX.
# 2026-01-29 14:50:04,537, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2016
# 2026-01-29 14:50:04,564, 2113979629.py, 8, INFO, Processing year 2017 for ticker ALDX.
# 2026-01-29 14:50:04,569, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2017
# 2026-01-29 14:50:04,611, 2113979629.py, 8, INFO, Processing year 2018 for ticker ALDX.
# 2026-01-29 14:50:04,623, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2018
# 2026-01-29 14:50:04,652, 2113979629.py, 8, INFO, Processing year 2019 for ticker ALDX.
# 2026-01-29 14:50:04,661, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2019
# 2026-01-29 14:50:04,698, 2113979629.py, 8, INFO, Processing year 2020 for ticker ALDX.
# 2026-01-29 14:50:04,713, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX\ALDX_2020
# 2026-01-29 14:50:04,748, 2113979629.py, 4, INFO, Processing ticker: GLADD
# 2026-01-29 14:50:04,761, 2113979629.py, 8, INFO, Processing year 2018 for ticker GLADD.
# 2026-01-29 14:50:04,768, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GLADD\GLADD_2018
# 2026-01-29 14:50:04,791, 2113979629.py, 8, INFO, Processing year 2019 for ticker GLADD.
# 2026-01-29 14:50:04,797, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GLADD\GLADD_2019
# 2026-01-29 14:50:04,815, 2113979629.py, 8, INFO, Processing year 2020 for ticker GLADD.
# 2026-01-29 14:50:04,815, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GLADD\GLADD_2020
# 2026-01-29 14:50:04,849, 2113979629.py, 4, INFO, Processing ticker: FIXX
# 2026-01-29 14:50:04,861, 2113979629.py, 8, INFO, Processing year 2018 for ticker FIXX.
# 2026-01-29 14:50:04,866, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/FIXX\FIXX_2018
# 2026-01-29 14:50:04,887, 2113979629.py, 8, INFO, Processing year 2019 for ticker FIXX.
# 2026-01-29 14:50:04,891, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/FIXX\FIXX_2019
# 2026-01-29 14:50:04,914, 2113979629.py, 8, INFO, Processing year 2020 for ticker FIXX.
# 2026-01-29 14:50:04,922, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/FIXX\FIXX_2020
# 2026-01-29 14:50:04,948, 2113979629.py, 4, INFO, Processing ticker: ETJ
# 2026-01-29 14:50:04,961, 2113979629.py, 8, INFO, Processing year 2007 for ticker ETJ.
# 2026-01-29 14:50:04,966, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2007
# 2026-01-29 14:50:04,986, 2113979629.py, 8, INFO, Processing year 2008 for ticker ETJ.
# 2026-01-29 14:50:04,998, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2008
# 2026-01-29 14:50:05,015, 2113979629.py, 8, INFO, Processing year 2009 for ticker ETJ.
# 2026-01-29 14:50:05,027, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2009
# 2026-01-29 14:50:05,051, 2113979629.py, 8, INFO, Processing year 2010 for ticker ETJ.
# 2026-01-29 14:50:05,057, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2010
# 2026-01-29 14:50:05,077, 2113979629.py, 8, INFO, Processing year 2011 for ticker ETJ.
# 2026-01-29 14:50:05,082, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2011
# 2026-01-29 14:50:05,103, 2113979629.py, 8, INFO, Processing year 2012 for ticker ETJ.
# 2026-01-29 14:50:05,107, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2012
# 2026-01-29 14:50:05,131, 2113979629.py, 8, INFO, Processing year 2013 for ticker ETJ.
# 2026-01-29 14:50:05,131, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2013
# 2026-01-29 14:50:05,165, 2113979629.py, 8, INFO, Processing year 2014 for ticker ETJ.
# 2026-01-29 14:50:05,170, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2014
# 2026-01-29 14:50:05,193, 2113979629.py, 8, INFO, Processing year 2015 for ticker ETJ.
# 2026-01-29 14:50:05,193, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2015
# 2026-01-29 14:50:05,211, 2113979629.py, 8, INFO, Processing year 2016 for ticker ETJ.
# 2026-01-29 14:50:05,228, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2016
# 2026-01-29 14:50:05,249, 2113979629.py, 8, INFO, Processing year 2017 for ticker ETJ.
# 2026-01-29 14:50:05,259, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2017
# 2026-01-29 14:50:05,276, 2113979629.py, 8, INFO, Processing year 2018 for ticker ETJ.
# 2026-01-29 14:50:05,282, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2018
# 2026-01-29 14:50:05,294, 2113979629.py, 8, INFO, Processing year 2019 for ticker ETJ.
# 2026-01-29 14:50:05,294, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2019
# 2026-01-29 14:50:05,329, 2113979629.py, 8, INFO, Processing year 2020 for ticker ETJ.
# 2026-01-29 14:50:05,331, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2020
# 2026-01-29 14:50:05,363, 2113979629.py, 4, INFO, Processing ticker: CMCTP
# 2026-01-29 14:50:05,372, 2113979629.py, 8, INFO, Processing year 2018 for ticker CMCTP.
# 2026-01-29 14:50:05,376, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2018
# 2026-01-29 14:50:05,398, 2113979629.py, 8, INFO, Processing year 2019 for ticker CMCTP.
# 2026-01-29 14:50:05,402, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2019
# 2026-01-29 14:50:05,423, 2113979629.py, 8, INFO, Processing year 2020 for ticker CMCTP.
# 2026-01-29 14:50:05,428, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2020
# 2026-01-29 14:50:05,448, 2113979629.py, 4, INFO, Processing ticker: BWG
# 2026-01-29 14:50:05,465, 2113979629.py, 8, INFO, Processing year 2012 for ticker BWG.
# 2026-01-29 14:50:05,471, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2012
# 2026-01-29 14:50:05,479, 2113979629.py, 8, INFO, Processing year 2013 for ticker BWG.
# 2026-01-29 14:50:05,496, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2013
# 2026-01-29 14:50:05,511, 2113979629.py, 8, INFO, Processing year 2014 for ticker BWG.
# 2026-01-29 14:50:05,511, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2014
# 2026-01-29 14:50:05,543, 2113979629.py, 8, INFO, Processing year 2015 for ticker BWG.
# 2026-01-29 14:50:05,545, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2015
# 2026-01-29 14:50:05,563, 2113979629.py, 8, INFO, Processing year 2016 for ticker BWG.
# 2026-01-29 14:50:05,563, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2016
# 2026-01-29 14:50:05,592, 2113979629.py, 8, INFO, Processing year 2017 for ticker BWG.
# 2026-01-29 14:50:05,599, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2017
# 2026-01-29 14:50:05,639, 2113979629.py, 8, INFO, Processing year 2018 for ticker BWG.
# 2026-01-29 14:50:05,647, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2018
# 2026-01-29 14:50:05,684, 2113979629.py, 8, INFO, Processing year 2019 for ticker BWG.
# 2026-01-29 14:50:05,692, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2019
# 2026-01-29 14:50:05,729, 2113979629.py, 8, INFO, Processing year 2020 for ticker BWG.
# 2026-01-29 14:50:05,736, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2020
# 2026-01-29 14:50:05,761, 2113979629.py, 4, INFO, Processing ticker: VIAC
# 2026-01-29 14:50:05,784, 2113979629.py, 8, INFO, Processing year 2005 for ticker VIAC.
# 2026-01-29 14:50:05,789, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2005
# 2026-01-29 14:50:05,817, 2113979629.py, 8, INFO, Processing year 2006 for ticker VIAC.
# 2026-01-29 14:50:05,823, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2006
# 2026-01-29 14:50:05,871, 2113979629.py, 8, INFO, Processing year 2007 for ticker VIAC.
# 2026-01-29 14:50:05,881, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2007
# 2026-01-29 14:50:05,923, 2113979629.py, 8, INFO, Processing year 2008 for ticker VIAC.
# 2026-01-29 14:50:05,925, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2008
# 2026-01-29 14:50:05,944, 2113979629.py, 8, INFO, Processing year 2009 for ticker VIAC.
# 2026-01-29 14:50:05,957, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2009
# 2026-01-29 14:50:05,980, 2113979629.py, 8, INFO, Processing year 2010 for ticker VIAC.
# 2026-01-29 14:50:05,980, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2010
# 2026-01-29 14:50:06,012, 2113979629.py, 8, INFO, Processing year 2011 for ticker VIAC.
# 2026-01-29 14:50:06,017, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2011
# 2026-01-29 14:50:06,041, 2113979629.py, 8, INFO, Processing year 2012 for ticker VIAC.
# 2026-01-29 14:50:06,047, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2012
# 2026-01-29 14:50:06,075, 2113979629.py, 8, INFO, Processing year 2013 for ticker VIAC.
# 2026-01-29 14:50:06,080, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2013
# 2026-01-29 14:50:06,095, 2113979629.py, 8, INFO, Processing year 2014 for ticker VIAC.
# 2026-01-29 14:50:06,095, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2014
# 2026-01-29 14:50:06,131, 2113979629.py, 8, INFO, Processing year 2015 for ticker VIAC.
# 2026-01-29 14:50:06,131, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2015
# 2026-01-29 14:50:06,160, 2113979629.py, 8, INFO, Processing year 2016 for ticker VIAC.
# 2026-01-29 14:50:06,165, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2016
# 2026-01-29 14:50:06,175, 2113979629.py, 8, INFO, Processing year 2017 for ticker VIAC.
# 2026-01-29 14:50:06,196, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2017
# 2026-01-29 14:50:06,211, 2113979629.py, 8, INFO, Processing year 2018 for ticker VIAC.
# 2026-01-29 14:50:06,230, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2018
# 2026-01-29 14:50:06,248, 2113979629.py, 8, INFO, Processing year 2019 for ticker VIAC.
# 2026-01-29 14:50:06,262, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2019
# 2026-01-29 14:50:06,276, 2113979629.py, 8, INFO, Processing year 2020 for ticker VIAC.
# 2026-01-29 14:50:06,293, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2020
# 2026-01-29 14:50:06,316, 2113979629.py, 4, INFO, Processing ticker: REI
# 2026-01-29 14:50:06,330, 2113979629.py, 8, INFO, Processing year 2007 for ticker REI.
# 2026-01-29 14:50:06,334, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2007
# 2026-01-29 14:50:06,359, 2113979629.py, 8, INFO, Processing year 2008 for ticker REI.
# 2026-01-29 14:50:06,365, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2008
# 2026-01-29 14:50:06,383, 2113979629.py, 8, INFO, Processing year 2009 for ticker REI.
# 2026-01-29 14:50:06,389, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2009
# 2026-01-29 14:50:06,409, 2113979629.py, 8, INFO, Processing year 2010 for ticker REI.
# 2026-01-29 14:50:06,412, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2010
# 2026-01-29 14:50:06,432, 2113979629.py, 8, INFO, Processing year 2011 for ticker REI.
# 2026-01-29 14:50:06,442, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2011
# 2026-01-29 14:50:06,467, 2113979629.py, 8, INFO, Processing year 2012 for ticker REI.
# 2026-01-29 14:50:06,479, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2012
# 2026-01-29 14:50:06,504, 2113979629.py, 8, INFO, Processing year 2013 for ticker REI.
# 2026-01-29 14:50:06,509, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2013
# 2026-01-29 14:50:06,532, 2113979629.py, 8, INFO, Processing year 2014 for ticker REI.
# 2026-01-29 14:50:06,541, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2014
# 2026-01-29 14:50:06,562, 2113979629.py, 8, INFO, Processing year 2015 for ticker REI.
# 2026-01-29 14:50:06,573, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2015
# 2026-01-29 14:50:06,595, 2113979629.py, 8, INFO, Processing year 2016 for ticker REI.
# 2026-01-29 14:50:06,595, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2016
# 2026-01-29 14:50:06,632, 2113979629.py, 8, INFO, Processing year 2017 for ticker REI.
# 2026-01-29 14:50:06,637, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2017
# 2026-01-29 14:50:06,660, 2113979629.py, 8, INFO, Processing year 2018 for ticker REI.
# 2026-01-29 14:50:06,666, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2018
# 2026-01-29 14:50:06,693, 2113979629.py, 8, INFO, Processing year 2019 for ticker REI.
# 2026-01-29 14:50:06,699, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2019
# 2026-01-29 14:50:06,728, 2113979629.py, 8, INFO, Processing year 2020 for ticker REI.
# 2026-01-29 14:50:06,734, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2020
# 2026-01-29 14:50:06,764, 2113979629.py, 4, INFO, Processing ticker: BLPH
# 2026-01-29 14:50:06,778, 2113979629.py, 8, INFO, Processing year 2015 for ticker BLPH.
# 2026-01-29 14:50:06,783, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2015
# 2026-01-29 14:50:06,808, 2113979629.py, 8, INFO, Processing year 2016 for ticker BLPH.
# 2026-01-29 14:50:06,814, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2016
# 2026-01-29 14:50:06,841, 2113979629.py, 8, INFO, Processing year 2017 for ticker BLPH.
# 2026-01-29 14:50:06,848, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2017
# 2026-01-29 14:50:06,878, 2113979629.py, 8, INFO, Processing year 2018 for ticker BLPH.
# 2026-01-29 14:50:06,883, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2018
# 2026-01-29 14:50:06,896, 2113979629.py, 8, INFO, Processing year 2019 for ticker BLPH.
# 2026-01-29 14:50:06,911, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2019
# 2026-01-29 14:50:06,932, 2113979629.py, 8, INFO, Processing year 2020 for ticker BLPH.
# 2026-01-29 14:50:06,937, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BLPH\BLPH_2020
# 2026-01-29 14:50:06,963, 2113979629.py, 4, INFO, Processing ticker: SMG
# 2026-01-29 14:50:06,977, 2113979629.py, 8, INFO, Processing year 1992 for ticker SMG.
# 2026-01-29 14:50:06,982, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1992
# 2026-01-29 14:50:07,010, 2113979629.py, 8, INFO, Processing year 1993 for ticker SMG.
# 2026-01-29 14:50:07,016, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1993
# 2026-01-29 14:50:07,039, 2113979629.py, 8, INFO, Processing year 1994 for ticker SMG.
# 2026-01-29 14:50:07,047, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1994
# 2026-01-29 14:50:07,061, 2113979629.py, 8, INFO, Processing year 1995 for ticker SMG.
# 2026-01-29 14:50:07,078, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1995
# 2026-01-29 14:50:07,110, 2113979629.py, 8, INFO, Processing year 1996 for ticker SMG.
# 2026-01-29 14:50:07,115, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1996
# 2026-01-29 14:50:07,133, 2113979629.py, 8, INFO, Processing year 1997 for ticker SMG.
# 2026-01-29 14:50:07,143, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1997
# 2026-01-29 14:50:07,162, 2113979629.py, 8, INFO, Processing year 1998 for ticker SMG.
# 2026-01-29 14:50:07,162, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1998
# 2026-01-29 14:50:07,192, 2113979629.py, 8, INFO, Processing year 1999 for ticker SMG.
# 2026-01-29 14:50:07,201, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1999
# 2026-01-29 14:50:07,228, 2113979629.py, 8, INFO, Processing year 2000 for ticker SMG.
# 2026-01-29 14:50:07,233, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2000
# 2026-01-29 14:50:07,253, 2113979629.py, 8, INFO, Processing year 2001 for ticker SMG.
# 2026-01-29 14:50:07,260, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2001
# 2026-01-29 14:50:07,275, 2113979629.py, 8, INFO, Processing year 2002 for ticker SMG.
# 2026-01-29 14:50:07,293, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2002
# 2026-01-29 14:50:07,313, 2113979629.py, 8, INFO, Processing year 2003 for ticker SMG.
# 2026-01-29 14:50:07,318, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2003
# 2026-01-29 14:50:07,344, 2113979629.py, 8, INFO, Processing year 2004 for ticker SMG.
# 2026-01-29 14:50:07,348, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2004
# 2026-01-29 14:50:07,369, 2113979629.py, 8, INFO, Processing year 2005 for ticker SMG.
# 2026-01-29 14:50:07,377, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2005
# 2026-01-29 14:50:07,398, 2113979629.py, 8, INFO, Processing year 2006 for ticker SMG.
# 2026-01-29 14:50:07,406, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2006
# 2026-01-29 14:50:07,432, 2113979629.py, 8, INFO, Processing year 2007 for ticker SMG.
# 2026-01-29 14:50:07,438, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2007
# 2026-01-29 14:50:07,459, 2113979629.py, 8, INFO, Processing year 2008 for ticker SMG.
# 2026-01-29 14:50:07,462, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2008
# 2026-01-29 14:50:07,483, 2113979629.py, 8, INFO, Processing year 2009 for ticker SMG.
# 2026-01-29 14:50:07,493, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2009
# 2026-01-29 14:50:07,511, 2113979629.py, 8, INFO, Processing year 2010 for ticker SMG.
# 2026-01-29 14:50:07,511, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2010
# 2026-01-29 14:50:07,543, 2113979629.py, 8, INFO, Processing year 2011 for ticker SMG.
# 2026-01-29 14:50:07,549, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2011
# 2026-01-29 14:50:07,579, 2113979629.py, 8, INFO, Processing year 2012 for ticker SMG.
# 2026-01-29 14:50:07,585, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2012
# 2026-01-29 14:50:07,595, 2113979629.py, 8, INFO, Processing year 2013 for ticker SMG.
# 2026-01-29 14:50:07,612, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2013
# 2026-01-29 14:50:07,633, 2113979629.py, 8, INFO, Processing year 2014 for ticker SMG.
# 2026-01-29 14:50:07,643, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2014
# 2026-01-29 14:50:07,665, 2113979629.py, 8, INFO, Processing year 2015 for ticker SMG.
# 2026-01-29 14:50:07,672, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2015
# 2026-01-29 14:50:07,694, 2113979629.py, 8, INFO, Processing year 2016 for ticker SMG.
# 2026-01-29 14:50:07,694, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2016
# 2026-01-29 14:50:07,725, 2113979629.py, 8, INFO, Processing year 2017 for ticker SMG.
# 2026-01-29 14:50:07,731, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2017
# 2026-01-29 14:50:07,792, 2113979629.py, 8, INFO, Processing year 2018 for ticker SMG.
# 2026-01-29 14:50:07,802, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2018
# 2026-01-29 14:50:07,829, 2113979629.py, 8, INFO, Processing year 2019 for ticker SMG.
# 2026-01-29 14:50:07,834, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2019
# 2026-01-29 14:50:07,864, 2113979629.py, 8, INFO, Processing year 2020 for ticker SMG.
# 2026-01-29 14:50:07,869, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2020
# 2026-01-29 14:50:07,898, 2113979629.py, 4, INFO, Processing ticker: MOH
# 2026-01-29 14:50:07,913, 2113979629.py, 8, INFO, Processing year 2003 for ticker MOH.
# 2026-01-29 14:50:07,918, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2003
# 2026-01-29 14:50:07,946, 2113979629.py, 8, INFO, Processing year 2004 for ticker MOH.
# 2026-01-29 14:50:07,951, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2004
# 2026-01-29 14:50:07,974, 2113979629.py, 8, INFO, Processing year 2005 for ticker MOH.
# 2026-01-29 14:50:07,980, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2005
# 2026-01-29 14:50:07,997, 2113979629.py, 8, INFO, Processing year 2006 for ticker MOH.
# 2026-01-29 14:50:08,010, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2006
# 2026-01-29 14:50:08,050, 2113979629.py, 8, INFO, Processing year 2007 for ticker MOH.
# 2026-01-29 14:50:08,058, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2007
# 2026-01-29 14:50:08,108, 2113979629.py, 8, INFO, Processing year 2008 for ticker MOH.
# 2026-01-29 14:50:08,115, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2008
# 2026-01-29 14:50:08,151, 2113979629.py, 8, INFO, Processing year 2009 for ticker MOH.
# 2026-01-29 14:50:08,163, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2009
# 2026-01-29 14:50:08,196, 2113979629.py, 8, INFO, Processing year 2010 for ticker MOH.
# 2026-01-29 14:50:08,208, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2010
# 2026-01-29 14:50:08,249, 2113979629.py, 8, INFO, Processing year 2011 for ticker MOH.
# 2026-01-29 14:50:08,254, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2011
# 2026-01-29 14:50:08,303, 2113979629.py, 8, INFO, Processing year 2012 for ticker MOH.
# 2026-01-29 14:50:08,314, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2012
# 2026-01-29 14:50:08,344, 2113979629.py, 8, INFO, Processing year 2013 for ticker MOH.
# 2026-01-29 14:50:08,352, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2013
# 2026-01-29 14:50:08,406, 2113979629.py, 8, INFO, Processing year 2014 for ticker MOH.
# 2026-01-29 14:50:08,409, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2014
# 2026-01-29 14:50:08,446, 2113979629.py, 8, INFO, Processing year 2015 for ticker MOH.
# 2026-01-29 14:50:08,450, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2015
# 2026-01-29 14:50:08,487, 2113979629.py, 8, INFO, Processing year 2016 for ticker MOH.
# 2026-01-29 14:50:08,501, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2016
# 2026-01-29 14:50:08,555, 2113979629.py, 8, INFO, Processing year 2017 for ticker MOH.
# 2026-01-29 14:50:08,559, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2017
# 2026-01-29 14:50:08,653, 2113979629.py, 8, INFO, Processing year 2018 for ticker MOH.
# 2026-01-29 14:50:08,675, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2018
# 2026-01-29 14:50:08,750, 2113979629.py, 8, INFO, Processing year 2019 for ticker MOH.
# 2026-01-29 14:50:08,755, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2019
# 2026-01-29 14:50:08,783, 2113979629.py, 8, INFO, Processing year 2020 for ticker MOH.
# 2026-01-29 14:50:08,791, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2020
# 2026-01-29 14:50:08,839, 2113979629.py, 4, INFO, Processing ticker: AMH
# 2026-01-29 14:50:08,854, 2113979629.py, 8, INFO, Processing year 2013 for ticker AMH.
# 2026-01-29 14:50:08,859, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2013
# 2026-01-29 14:50:08,946, 2113979629.py, 8, INFO, Processing year 2014 for ticker AMH.
# 2026-01-29 14:50:08,966, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2014
# 2026-01-29 14:50:09,016, 2113979629.py, 8, INFO, Processing year 2015 for ticker AMH.
# 2026-01-29 14:50:09,027, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2015
# 2026-01-29 14:50:09,080, 2113979629.py, 8, INFO, Processing year 2016 for ticker AMH.
# 2026-01-29 14:50:09,088, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2016
# 2026-01-29 14:50:09,133, 2113979629.py, 8, INFO, Processing year 2017 for ticker AMH.
# 2026-01-29 14:50:09,139, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2017
# 2026-01-29 14:50:09,162, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMH.
# 2026-01-29 14:50:09,168, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2018
# 2026-01-29 14:50:09,195, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMH.
# 2026-01-29 14:50:09,195, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2019
# 2026-01-29 14:50:09,232, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMH.
# 2026-01-29 14:50:09,235, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_2020
# 2026-01-29 14:50:09,261, 2113979629.py, 4, INFO, Processing ticker: AMAL
# 2026-01-29 14:50:09,277, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMAL.
# 2026-01-29 14:50:09,281, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAL\AMAL_2018
# 2026-01-29 14:50:09,311, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMAL.
# 2026-01-29 14:50:09,314, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAL\AMAL_2019
# 2026-01-29 14:50:09,345, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMAL.
# 2026-01-29 14:50:09,346, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAL\AMAL_2020
# 2026-01-29 14:50:09,377, 2113979629.py, 4, INFO, Processing ticker: BPYPN
# 2026-01-29 14:50:09,391, 2113979629.py, 8, INFO, Processing year 2020 for ticker BPYPN.
# 2026-01-29 14:50:09,398, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BPYPN\BPYPN_2020
# 2026-01-29 14:50:09,426, 2113979629.py, 4, INFO, Processing ticker: ERH
# 2026-01-29 14:50:09,439, 2113979629.py, 8, INFO, Processing year 2004 for ticker ERH.
# 2026-01-29 14:50:09,446, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2004
# 2026-01-29 14:50:09,483, 2113979629.py, 8, INFO, Processing year 2005 for ticker ERH.
# 2026-01-29 14:50:09,489, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2005
# 2026-01-29 14:50:09,515, 2113979629.py, 8, INFO, Processing year 2006 for ticker ERH.
# 2026-01-29 14:50:09,515, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2006
# 2026-01-29 14:50:09,542, 2113979629.py, 8, INFO, Processing year 2007 for ticker ERH.
# 2026-01-29 14:50:09,554, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2007
# 2026-01-29 14:50:09,579, 2113979629.py, 8, INFO, Processing year 2008 for ticker ERH.
# 2026-01-29 14:50:09,587, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2008
# 2026-01-29 14:50:09,622, 2113979629.py, 8, INFO, Processing year 2009 for ticker ERH.
# 2026-01-29 14:50:09,628, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2009
# 2026-01-29 14:50:09,660, 2113979629.py, 8, INFO, Processing year 2010 for ticker ERH.
# 2026-01-29 14:50:09,668, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2010
# 2026-01-29 14:50:09,702, 2113979629.py, 8, INFO, Processing year 2011 for ticker ERH.
# 2026-01-29 14:50:09,707, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2011
# 2026-01-29 14:50:09,728, 2113979629.py, 8, INFO, Processing year 2012 for ticker ERH.
# 2026-01-29 14:50:09,739, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2012
# 2026-01-29 14:50:09,761, 2113979629.py, 8, INFO, Processing year 2013 for ticker ERH.
# 2026-01-29 14:50:09,770, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2013
# 2026-01-29 14:50:09,801, 2113979629.py, 8, INFO, Processing year 2014 for ticker ERH.
# 2026-01-29 14:50:09,807, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2014
# 2026-01-29 14:50:09,838, 2113979629.py, 8, INFO, Processing year 2015 for ticker ERH.
# 2026-01-29 14:50:09,846, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2015
# 2026-01-29 14:50:09,866, 2113979629.py, 8, INFO, Processing year 2016 for ticker ERH.
# 2026-01-29 14:50:09,874, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2016
# 2026-01-29 14:50:09,898, 2113979629.py, 8, INFO, Processing year 2017 for ticker ERH.
# 2026-01-29 14:50:09,898, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ERH\ERH_2017
# 2026-01-29 14:50:09,928, 2113979629.py, 8, INFO, Processing year 2018 for ticker ERH.
# ...
# 2026-01-29 14:51:03,864, 2113979629.py, 8, INFO, Processing year 2016 for ticker GURE.
# 2026-01-29 14:51:03,885, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2016
# 2026-01-29 14:51:03,985, 2113979629.py, 8, INFO, Processing year 2017 for ticker GURE.
# 2026-01-29 14:51:04,004, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2017
# 2026-01-29 14:51:04,065, 2113979629.py, 8, INFO, Processing year 2018 for ticker GURE.
# 2026-01-29 14:51:04,075, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2018
# 2026-01-29 14:51:04,125, 2113979629.py, 8, INFO, Processing year 2019 for ticker GURE.
# 2026-01-29 14:51:04,141, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2019
# 2026-01-29 14:51:04,207, 2113979629.py, 8, INFO, Processing year 2020 for ticker GURE.
# 2026-01-29 14:51:04,245, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GURE\GURE_2020
# 2026-01-29 14:51:04,326, 2113979629.py, 4, INFO, Processing ticker: TEF
# 2026-01-29 14:51:04,385, 2113979629.py, 8, INFO, Processing year 1987 for ticker TEF.
# 2026-01-29 14:51:04,408, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1987
# 2026-01-29 14:51:04,532, 2113979629.py, 8, INFO, Processing year 1988 for ticker TEF.
# 2026-01-29 14:51:04,541, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1988
# 2026-01-29 14:51:04,580, 2113979629.py, 8, INFO, Processing year 1989 for ticker TEF.
# 2026-01-29 14:51:04,595, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1989
# 2026-01-29 14:51:04,650, 2113979629.py, 8, INFO, Processing year 1990 for ticker TEF.
# 2026-01-29 14:51:04,665, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1990
# 2026-01-29 14:51:04,720, 2113979629.py, 8, INFO, Processing year 1991 for ticker TEF.
# 2026-01-29 14:51:04,735, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1991
# 2026-01-29 14:51:04,820, 2113979629.py, 8, INFO, Processing year 1992 for ticker TEF.
# 2026-01-29 14:51:04,850, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1992
# 2026-01-29 14:51:04,950, 2113979629.py, 8, INFO, Processing year 1993 for ticker TEF.
# 2026-01-29 14:51:04,984, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1993
# 2026-01-29 14:51:05,045, 2113979629.py, 8, INFO, Processing year 1994 for ticker TEF.
# 2026-01-29 14:51:05,070, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1994
# 2026-01-29 14:51:05,148, 2113979629.py, 8, INFO, Processing year 1995 for ticker TEF.
# 2026-01-29 14:51:05,170, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1995
# 2026-01-29 14:51:05,245, 2113979629.py, 8, INFO, Processing year 1996 for ticker TEF.
# 2026-01-29 14:51:05,275, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1996
# 2026-01-29 14:51:05,408, 2113979629.py, 8, INFO, Processing year 1997 for ticker TEF.
# 2026-01-29 14:51:05,435, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1997
# 2026-01-29 14:51:05,499, 2113979629.py, 8, INFO, Processing year 1998 for ticker TEF.
# 2026-01-29 14:51:05,514, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1998
# 2026-01-29 14:51:05,626, 2113979629.py, 8, INFO, Processing year 1999 for ticker TEF.
# 2026-01-29 14:51:05,657, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_1999
# 2026-01-29 14:51:05,735, 2113979629.py, 8, INFO, Processing year 2000 for ticker TEF.
# 2026-01-29 14:51:05,750, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2000
# 2026-01-29 14:51:05,841, 2113979629.py, 8, INFO, Processing year 2001 for ticker TEF.
# 2026-01-29 14:51:05,855, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2001
# 2026-01-29 14:51:05,965, 2113979629.py, 8, INFO, Processing year 2002 for ticker TEF.
# 2026-01-29 14:51:05,990, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2002
# 2026-01-29 14:51:06,065, 2113979629.py, 8, INFO, Processing year 2003 for ticker TEF.
# 2026-01-29 14:51:06,075, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2003
# 2026-01-29 14:51:06,195, 2113979629.py, 8, INFO, Processing year 2004 for ticker TEF.
# 2026-01-29 14:51:06,224, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2004
# 2026-01-29 14:51:06,314, 2113979629.py, 8, INFO, Processing year 2005 for ticker TEF.
# 2026-01-29 14:51:06,335, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2005
# 2026-01-29 14:51:06,430, 2113979629.py, 8, INFO, Processing year 2006 for ticker TEF.
# 2026-01-29 14:51:06,450, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2006
# 2026-01-29 14:51:06,555, 2113979629.py, 8, INFO, Processing year 2007 for ticker TEF.
# 2026-01-29 14:51:06,576, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2007
# 2026-01-29 14:51:06,665, 2113979629.py, 8, INFO, Processing year 2008 for ticker TEF.
# 2026-01-29 14:51:06,694, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2008
# 2026-01-29 14:51:06,808, 2113979629.py, 8, INFO, Processing year 2009 for ticker TEF.
# 2026-01-29 14:51:06,830, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2009
# 2026-01-29 14:51:06,908, 2113979629.py, 8, INFO, Processing year 2010 for ticker TEF.
# 2026-01-29 14:51:06,935, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2010
# 2026-01-29 14:51:07,025, 2113979629.py, 8, INFO, Processing year 2011 for ticker TEF.
# 2026-01-29 14:51:07,034, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2011
# 2026-01-29 14:51:07,106, 2113979629.py, 8, INFO, Processing year 2012 for ticker TEF.
# 2026-01-29 14:51:07,125, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2012
# 2026-01-29 14:51:07,208, 2113979629.py, 8, INFO, Processing year 2013 for ticker TEF.
# 2026-01-29 14:51:07,230, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2013
# 2026-01-29 14:51:07,280, 2113979629.py, 8, INFO, Processing year 2014 for ticker TEF.
# 2026-01-29 14:51:07,293, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2014
# 2026-01-29 14:51:07,344, 2113979629.py, 8, INFO, Processing year 2015 for ticker TEF.
# 2026-01-29 14:51:07,358, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2015
# 2026-01-29 14:51:07,420, 2113979629.py, 8, INFO, Processing year 2016 for ticker TEF.
# 2026-01-29 14:51:07,435, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2016
# 2026-01-29 14:51:07,506, 2113979629.py, 8, INFO, Processing year 2017 for ticker TEF.
# 2026-01-29 14:51:07,520, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2017
# 2026-01-29 14:51:07,602, 2113979629.py, 8, INFO, Processing year 2018 for ticker TEF.
# 2026-01-29 14:51:07,620, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2018
# 2026-01-29 14:51:07,745, 2113979629.py, 8, INFO, Processing year 2019 for ticker TEF.
# 2026-01-29 14:51:07,758, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2019
# 2026-01-29 14:51:07,815, 2113979629.py, 8, INFO, Processing year 2020 for ticker TEF.
# 2026-01-29 14:51:07,835, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2020
# 2026-01-29 14:51:07,897, 2113979629.py, 4, INFO, Processing ticker: SYNH
# 2026-01-29 14:51:07,945, 2113979629.py, 8, INFO, Processing year 2014 for ticker SYNH.
# 2026-01-29 14:51:07,958, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2014
# 2026-01-29 14:51:08,015, 2113979629.py, 8, INFO, Processing year 2015 for ticker SYNH.
# 2026-01-29 14:51:08,025, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2015
# 2026-01-29 14:51:08,074, 2113979629.py, 8, INFO, Processing year 2016 for ticker SYNH.
# 2026-01-29 14:51:08,085, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2016
# 2026-01-29 14:51:08,142, 2113979629.py, 8, INFO, Processing year 2017 for ticker SYNH.
# 2026-01-29 14:51:08,158, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2017
# 2026-01-29 14:51:08,245, 2113979629.py, 8, INFO, Processing year 2018 for ticker SYNH.
# 2026-01-29 14:51:08,270, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2018
# 2026-01-29 14:51:08,358, 2113979629.py, 8, INFO, Processing year 2019 for ticker SYNH.
# 2026-01-29 14:51:08,380, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2019
# 2026-01-29 14:51:08,470, 2113979629.py, 8, INFO, Processing year 2020 for ticker SYNH.
# 2026-01-29 14:51:08,491, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2020
# 2026-01-29 14:51:08,627, 2113979629.py, 4, INFO, Processing ticker: KEY
# 2026-01-29 14:51:08,692, 2113979629.py, 8, INFO, Processing year 1987 for ticker KEY.
# 2026-01-29 14:51:08,701, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1987
# 2026-01-29 14:51:08,760, 2113979629.py, 8, INFO, Processing year 1988 for ticker KEY.
# 2026-01-29 14:51:08,802, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1988
# 2026-01-29 14:51:08,893, 2113979629.py, 8, INFO, Processing year 1989 for ticker KEY.
# 2026-01-29 14:51:08,900, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1989
# 2026-01-29 14:51:08,941, 2113979629.py, 8, INFO, Processing year 1990 for ticker KEY.
# 2026-01-29 14:51:08,949, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1990
# 2026-01-29 14:51:08,992, 2113979629.py, 8, INFO, Processing year 1991 for ticker KEY.
# 2026-01-29 14:51:09,002, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1991
# 2026-01-29 14:51:09,041, 2113979629.py, 8, INFO, Processing year 1992 for ticker KEY.
# 2026-01-29 14:51:09,047, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1992
# 2026-01-29 14:51:09,141, 2113979629.py, 8, INFO, Processing year 1993 for ticker KEY.
# 2026-01-29 14:51:09,166, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1993
# 2026-01-29 14:51:09,259, 2113979629.py, 8, INFO, Processing year 1994 for ticker KEY.
# 2026-01-29 14:51:09,280, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1994
# 2026-01-29 14:51:09,401, 2113979629.py, 8, INFO, Processing year 1995 for ticker KEY.
# 2026-01-29 14:51:09,408, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1995
# 2026-01-29 14:51:09,449, 2113979629.py, 8, INFO, Processing year 1996 for ticker KEY.
# 2026-01-29 14:51:09,458, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1996
# 2026-01-29 14:51:09,502, 2113979629.py, 8, INFO, Processing year 1997 for ticker KEY.
# 2026-01-29 14:51:09,508, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1997
# 2026-01-29 14:51:09,548, 2113979629.py, 8, INFO, Processing year 1998 for ticker KEY.
# 2026-01-29 14:51:09,557, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1998
# 2026-01-29 14:51:09,598, 2113979629.py, 8, INFO, Processing year 1999 for ticker KEY.
# 2026-01-29 14:51:09,607, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1999
# 2026-01-29 14:51:09,653, 2113979629.py, 8, INFO, Processing year 2000 for ticker KEY.
# 2026-01-29 14:51:09,663, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2000
# 2026-01-29 14:51:09,728, 2113979629.py, 8, INFO, Processing year 2001 for ticker KEY.
# 2026-01-29 14:51:09,763, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2001
# 2026-01-29 14:51:09,859, 2113979629.py, 8, INFO, Processing year 2002 for ticker KEY.
# 2026-01-29 14:51:09,867, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2002
# 2026-01-29 14:51:09,922, 2113979629.py, 8, INFO, Processing year 2003 for ticker KEY.
# 2026-01-29 14:51:09,977, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2003
# 2026-01-29 14:51:10,097, 2113979629.py, 8, INFO, Processing year 2004 for ticker KEY.
# 2026-01-29 14:51:10,105, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2004
# 2026-01-29 14:51:10,146, 2113979629.py, 8, INFO, Processing year 2005 for ticker KEY.
# 2026-01-29 14:51:10,151, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2005
# 2026-01-29 14:51:10,197, 2113979629.py, 8, INFO, Processing year 2006 for ticker KEY.
# 2026-01-29 14:51:10,205, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2006
# 2026-01-29 14:51:10,247, 2113979629.py, 8, INFO, Processing year 2007 for ticker KEY.
# 2026-01-29 14:51:10,251, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2007
# 2026-01-29 14:51:10,302, 2113979629.py, 8, INFO, Processing year 2008 for ticker KEY.
# 2026-01-29 14:51:10,322, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2008
# 2026-01-29 14:51:10,392, 2113979629.py, 8, INFO, Processing year 2009 for ticker KEY.
# 2026-01-29 14:51:10,422, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2009
# 2026-01-29 14:51:10,558, 2113979629.py, 8, INFO, Processing year 2010 for ticker KEY.
# 2026-01-29 14:51:10,582, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2010
# 2026-01-29 14:51:10,627, 2113979629.py, 8, INFO, Processing year 2011 for ticker KEY.
# 2026-01-29 14:51:10,643, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2011
# 2026-01-29 14:51:10,778, 2113979629.py, 8, INFO, Processing year 2012 for ticker KEY.
# 2026-01-29 14:51:10,807, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2012
# 2026-01-29 14:51:10,868, 2113979629.py, 8, INFO, Processing year 2013 for ticker KEY.
# 2026-01-29 14:51:10,896, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2013
# 2026-01-29 14:51:11,020, 2113979629.py, 8, INFO, Processing year 2014 for ticker KEY.
# 2026-01-29 14:51:11,029, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2014
# 2026-01-29 14:51:11,070, 2113979629.py, 8, INFO, Processing year 2015 for ticker KEY.
# 2026-01-29 14:51:11,080, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2015
# 2026-01-29 14:51:11,135, 2113979629.py, 8, INFO, Processing year 2016 for ticker KEY.
# 2026-01-29 14:51:11,155, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2016
# 2026-01-29 14:51:11,245, 2113979629.py, 8, INFO, Processing year 2017 for ticker KEY.
# 2026-01-29 14:51:11,265, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2017
# 2026-01-29 14:51:11,409, 2113979629.py, 8, INFO, Processing year 2018 for ticker KEY.
# 2026-01-29 14:51:11,435, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2018
# 2026-01-29 14:51:11,565, 2113979629.py, 8, INFO, Processing year 2019 for ticker KEY.
# 2026-01-29 14:51:11,585, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2019
# 2026-01-29 14:51:11,665, 2113979629.py, 8, INFO, Processing year 2020 for ticker KEY.
# 2026-01-29 14:51:11,675, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2020

# %% [markdown]
# Why would we want to store data this way?
#
# + Data files are easier to maintain. We do not update old data, only recent data or the most recent "delta".
# + Parquet files, as long as they maintain a consistent schema, can all be read jointly.

# %% [markdown]
# # Load, Transform, and Save
#
# In this section, we will load the Parquet files we generated, transform the data, and save the resulting dataset.

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to obtain the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
_logs.info(f'Found {len(parquet_files)} parquet files for reading back into Dask.')

dd_px = dd.read_parquet(parquet_files).set_index("ticker")
# Out:
# 2026-01-29 15:00:13,633, 174194153.py, 4, INFO, Found 2045 parquet files for reading back into Dask.

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work similarly to Pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.
#
# In the code below, the following operation occurs:
#
# + Start with a Dask dataframe, `dd_px`.
# + Group the rows of this dataframe by the variable `ticker`, i.e., each group will contain the observations that pertain only to one ticker at a time. The `group_key` parameter controls whether an index entry is added with the value of the grouping variable (`ticker` in this case); if we made `group_keys=True`, we would have a duplicate `ticker` column.
# + For each group defined by a `ticker`, `apply()` the following calculation:
#
#     - Sort the values by `Date` in ascending order.
#     - Assign a new variable called `Close_lag_1` by shifting the position of the closing price (`Close`) by one position.
#     - Define the schema of the resulting dataframe. If we omit this specification, we would get a warning; however, the simplicity of the calculation ensures that Dask can determine the resulting schema.

# %%
dd_px
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year
# npartitions=60
# ACN             datetime64[ns]  float64  float64  float64  float64   float64  float64  string  int32
# ALDX                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# Dask Name: setindex, 2 expressions
# Expr=SetIndex(frame=ReadParquetFSSpec(fb96758), _other='ticker', options={})

# %%
dd_shift = (
    dd_px
        .groupby('ticker', group_keys=False)
        .apply(
            lambda x: x.sort_values('Date', ascending = True)
                       .assign(Close_lag_1 = x['Close'].shift(1)), 
            meta = pd.DataFrame(data ={'Date': 'datetime64[ns]',
                    'Open': 'f8',
                    'High': 'f8',
                    'Low': 'f8',
                    'Close': 'f8',
                    'Adj Close': 'f8',
                    'Volume': 'i8',
                    'source': 'object',
                    'Year': 'int32',
                    'Close_lag_1': 'f8'},
                    index = pd.Index([], dtype=pd.StringDtype(), name='ticker'))
    ))

# %% [markdown]
# Finally, using the dataframe that we created above, we can now `assign` the `Returns` variable to the entire dataset.

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# Question: How do we know that we are not (erroneously) combining the last price of a ticker with the first price of the next ticker?

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low   Close Adj Close  Volume  source    Year Close_lag_1 Returns
# npartitions=60
# ACN             object  object  object  object  object    object  object  object  object      object  object
# ALDX               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ...                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZIXI               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZIXI               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(fb96758), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x0000019AF564FD80>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until the computation is required.
# + To trigger an execution in dask use `.compute()` or execute a command that requires the actual values (for example, write to Parquet or SQL).

# %%
dd_rets.compute()
# Out:
#              Date   Open   High    Low  Close  Adj Close      Volume  \
# ticker
# ACN    2001-07-19  15.10  15.29  15.00  15.17  11.404394  34994300.0
# ACN    2001-07-20  15.05  15.05  14.80  15.01  11.284108   9238500.0
# ACN    2001-07-23  15.00  15.01  14.55  15.00  11.276587   7501000.0
# ACN    2001-07-24  14.95  14.97  14.70  14.86  11.171341   3537300.0
# ACN    2001-07-25  14.70  14.95  14.65  14.95  11.238999   4208100.0
# ...           ...    ...    ...    ...    ...        ...         ...
# ZIXI   2020-03-26   4.06   4.53   3.88   4.51   4.510000   1668500.0
# ZIXI   2020-03-27   4.49   4.71   4.10   4.60   4.600000   1146800.0
# ZIXI   2020-03-30   4.83   4.87   4.44   4.64   4.640000   1212000.0
# ZIXI   2020-03-31   4.60   4.69   4.10   4.31   4.310000   1057200.0
# ZIXI   2020-04-01   4.11   4.16   3.80   3.82   3.820000    539500.0
#
#           source  Year  Close_lag_1   Returns
# ticker
# ACN      ACN.csv  2001          NaN       NaN
# ACN      ACN.csv  2001        15.17 -0.010547
# ACN      ACN.csv  2001        15.01 -0.000666
# ACN      ACN.csv  2001        15.00 -0.009333
# ACN      ACN.csv  2001        14.86  0.006057
# ...          ...   ...          ...       ...
# ZIXI    ZIXI.csv  2020         4.04  0.116337
# ZIXI    ZIXI.csv  2020         4.00  0.150000
# ZIXI    ZIXI.csv  2020         3.85  0.205195
# ZIXI    ZIXI.csv  2020         3.77  0.143236
# ZIXI    ZIXI.csv  2020         3.78  0.010582
#
# [239659 rows x 11 columns]

# %%
df = dd_rets.compute()
df.to_csv("test.csv")

# %%
df.head()
# Out:
#              Date   Open   High    Low  Close  Adj Close      Volume   source  \
# ticker
# ACN    2001-07-19  15.10  15.29  15.00  15.17  11.404394  34994300.0  ACN.csv
# ACN    2001-07-20  15.05  15.05  14.80  15.01  11.284108   9238500.0  ACN.csv
# ACN    2001-07-23  15.00  15.01  14.55  15.00  11.276587   7501000.0  ACN.csv
# ACN    2001-07-24  14.95  14.97  14.70  14.86  11.171341   3537300.0  ACN.csv
# ACN    2001-07-25  14.70  14.95  14.65  14.95  11.238999   4208100.0  ACN.csv
#
#         Year  Close_lag_1   Returns
# ticker
# ACN     2001          NaN       NaN
# ACN     2001        15.17 -0.010547
# ACN     2001        15.01 -0.000666
# ACN     2001        15.00 -0.009333
# ACN     2001        14.86  0.006057

# %% [markdown]
# ## Save
#
# With our transformed data, we can now save the new feature to a Parquet file. We will need to answer the following questions depending on our context, setup, and available resources:
#
# + Should we keep the same namespace?
# + Should we save all columns?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low   Close Adj Close  Volume  source    Year Close_lag_1 Returns
# npartitions=60
# ACN             object  object  object  object  object    object  object  object  object      object  object
# ALDX               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ...                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZIXI               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZIXI               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(fb96758), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x0000019AF564FD80>, args=(), kwargs={})))

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, 
                   overwrite = True, 
                   schema={
                       'Date': 'timestamp[ns]',
                       'Open': 'float64',
                       'High': 'float64',
                       'Low': 'float64',
                       'Close': 'float64',
                       'Adj Close': 'float64',
                       'Volume': 'int64',
                       'source': 'string',
                       'Year': 'int32',
                       'Close_lag_1': 'float64',
                       'Returns': 'float64',
                       'ticker': 'large_string'
                   })

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
